# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Entradas
# ## Variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 2 # Asignación de valor a la variable

# %%
id(a) # la función id permite conocer la dirección de memoria donde se almacena el valor de la variable
# Out:
# 105920144816008

# %%
print(a) #leer el valor de la variable
# Out:
# 2
